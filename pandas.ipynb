# %% [markdown]
# <a href="https://colab.research.google.com/github/LAXMANPANT123/python-projects/blob/laxman/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = {'Name':['A','B','C'],'Age':[20,25,30],'City':['Delhi','Mumbai','Chennai']}
df = pd.DataFrame(data)

# %%
df.head()  # it shows the first five rows
# Out:
#   Name  Age     City
# 0    A   20    Delhi
# 1    B   25   Mumbai
# 2    C   30  Chennai

# %%
df.tail()  # it shows the last five rows
# Out:
#   Name  Age     City
# 0    A   20    Delhi
# 1    B   25   Mumbai
# 2    C   30  Chennai

# %%
df.index
# Out:
# RangeIndex(start=0, stop=3, step=1)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'City'], dtype='object')

# %%
df.shape
# Out:
# (3, 3)

# %%
df.describe()
# Out:
#         Age
# count   3.0
# mean   25.0
# std     5.0
# min    20.0
# 25%    22.5
# 50%    25.0
# 75%    27.5
# max    30.0

# %%
df['Name']
# Out:
# 0    A
# 1    B
# 2    C
# Name: Name, dtype: object

# %%
df.loc[0]  #select row by index
# Out:
# Name        A
# Age        20
# City    Delhi
# Name: 0, dtype: object

# %%
df[df['Age'] > 22]
# Out:
#   Name  Age     City
# 1    B   25   Mumbai
# 2    C   30  Chennai

# %%
df['Salary'] = [30000, 40000, 50000]

# %%
df['Age'] = df['Age']+1

# %%
df.head()
# Out:
#   Name  Age     City  Salary
# 0    A   21    Delhi   30000
# 1    B   26   Mumbai   40000
# 2    C   31  Chennai   50000

# %%
df.drop('City', axis=1)
# Out:
#   Name  Age  Salary
# 0    A   21   30000
# 1    B   26   40000
# 2    C   31   50000

# %%
df.rename(columns={'Name': 'FullName'})
# Out:
#   FullName  Age     City  Salary
# 0        A   21    Delhi   30000
# 1        B   26   Mumbai   40000
# 2        C   31  Chennai   50000

# %%
df.sort_values('Age')
# Out:
#   Name  Age     City  Salary
# 0    A   21    Delhi   30000
# 1    B   26   Mumbai   40000
# 2    C   31  Chennai   50000

# %%
df.loc[2, "Age"] = 30

# %%
df.head()
# Out:
#   Name  Age     City  Salary
# 0    A   21    Delhi   30000
# 1    B   26   Mumbai   40000
# 2    C   30  Chennai   50000

# %%
df.fillna(0)   # fidm all nan value and replace them with 0
# Out:
#   Name  Age     City  Salary
# 0    A   21    Delhi   30000
# 1    B   26   Mumbai   40000
# 2    C   30  Chennai   50000

# %%
df['Age'].apply(lambda x:x*2)
# Out:
# 0    42
# 1    52
# 2    60
# Name: Age, dtype: int64

# %%
df['Age'].apply(lambda x: x + 5)
# Out:
# 0    26
# 1    31
# 2    35
# Name: Age, dtype: int64

# %%
df.groupby('City')['Salary'].mean()
# Out:
# City
# Chennai    50000.0
# Delhi      30000.0
# Mumbai     40000.0
# Name: Salary, dtype: float64

# %%
df['City'].value_counts()
# Out:
# City
# Delhi      1
# Mumbai     1
# Chennai    1
# Name: count, dtype: int64
